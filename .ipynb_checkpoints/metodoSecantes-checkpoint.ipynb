# %% [markdown]
# ***METODO DE LAS SECANTES***

# %% [markdown]
# **CODIGO**

# %%
import numpy as np

def f(x):
    return np.exp(x) - 4 + x


def secantes(f, x0, x1, stop, maxiter):
    """
    f : funcion matematica
    x0, x1: puntos iniciales en x
    stop, maxiter : criterios de detencion
    """
    secantes = list()
    
    i = 0
    while True:
        i = i+1 # Contar un nuevo ciclo
        p0 = (x0, f(x0)) # f en x0
        p1 = (x1, f(x1)) # f en x1
        secantes.append([p0, p1]) # Se agregan los puntos que forman la secante 

        x2 = x1 - ((x1-x0) / (p1[1]-p0[1]))*p1[1] # Siguiente iteracion

        if abs(x2 - x1) < stop or i > maxiter:
            break
            
        else:
            x0 = x1
            x1 = x2
            continue
    
    return secantes

# %%
# EJEMPLO1---------------------------------

# Criterios de paro
detencion = 10**-3
maxiteraciones = 10

#Selecciono dos puntos iniciales
inicial0 = -2
inicial1 = 2

ejemplo1 = secantes(f, inicial0, inicial1, detencion, maxiteraciones)

for s in ejemplo1:
    print(s)

print(len(ejemplo1))
# Out:
# [(-2, np.float64(-5.864664716763388)), (2, np.float64(5.38905609893065))]
# [(2, np.float64(5.38905609893065)), (np.float64(0.08452468754502407), np.float64(-2.827275603575276))]
# [(np.float64(0.08452468754502407), np.float64(-2.827275603575276)), (np.float64(0.743648103716619), np.float64(-1.1527562276258903))]
# [(np.float64(0.743648103716619), np.float64(-1.1527562276258903)), (np.float64(1.1973953900596488), np.float64(0.5088759553098021))]
# [(np.float64(1.1973953900596488), np.float64(0.5088759553098021)), (np.float64(1.0584349834315738), np.float64(-0.059707712803726))]
# [(np.float64(1.0584349834315738), np.float64(-0.059707712803726)), (np.float64(1.0730273970293231), np.float64(-0.002753718343862177))]
# 6

# %% [markdown]
# **GRAFICAS**

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# plot config
ax.grid(True, which="both", linestyle="--", alpha=0.5)
ax.spines["left"].set_position("zero")
ax.spines["bottom"].set_position("zero")
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")

# ELEMENTOS A GRAFICAR:
xs = np.linspace(-3,3,1000)
y = np.exp(xs) - 4 + xs
ax.plot(xs, y)

grafx = []
grafy = []

for secante in ejemplo1:
    grafx = [secante[0][0], secante[1][0]]
    grafy = [secante[0][1], secante[1][1]]
    ax.plot(grafx, grafy)
